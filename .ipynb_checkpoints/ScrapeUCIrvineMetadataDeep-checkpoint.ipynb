# %%
import requests
import lxml.html as lh
import pandas as pd
import numpy as np
from IPython.display import display, HTML
import matplotlib.pyplot as plt # required for data visualization purposes.
from BeautifulSoup import BeautifulSoup, SoupStrainer
from bs4 import BeautifulSoup

# %%
starting_url = 'https://archive.ics.uci.edu/ml/'
url='https://archive.ics.uci.edu/ml/datasets.html'
page = requests.get(url)
soup = BeautifulSoup(page.content, 'html.parser')
#print soup.prettify()

# %%
def scrape_url(url, index):
    response = requests.get(url)
    if (response.content == None):
        return [],[None] * 9
    soup = BeautifulSoup(response.content, "html.parser")
    header = soup.find("b", text="Number of Instances:")
    if (header == None):
        return [],[None] * 9
    table = header.find_parent("table")
    dictionary_to_df= {}
    first = 0 
    data = []
    data.append(index)
    columns = []
    columns.append('DataSet Name')
    for row in table.find_all("tr"):
        L= row.find_all("td")
        for cell in L[1::2]:
            data.append(cell.get_text(strip=True))
        for cell in L[0::2] :
            columns.append(cell.get_text(strip=True))
    return columns, data

# %%
columns, data = scrape_url('https://archive.ics.uci.edu/ml/datasets/Abalone', 'Abalone')
print columns
print data
# Out:
# ['DataSet Name', u'Data Set Characteristics:', u'Number of Instances:', u'Area:', u'Attribute Characteristics:', u'Number of Attributes:', u'Date Donated', u'Associated Tasks:', u'Missing Values?', u'Number of Web Hits:']
# ['Abalone', u'Multivariate', u'4177', u'Life', u'Categorical, Integer, Real', u'8', u'1995-12-01', u'Classification', u'No', u'674010']

# %%
start_now = 0
list_of_data = []
for link in soup.findAll('a'):
    if link.has_attr('href'):
        if link.get_text(strip=True) == 'Abalone':
            columns, data = scrape_url(starting_url+link['href'], 'Abalone' ) 
            start_now = 1
        if start_now == 0 or link.get_text(strip=True) == '':            
            continue
        #print link.get_text(strip=True), link['href']
        #print '==============================================================='
        cols, data = scrape_url(starting_url+link['href'], link.get_text(strip=True))
        #print columns,data
        list_of_data.append(data)
        #print '==============================================================='

# %%
data = pd.DataFrame(list_of_data, columns=columns)
data.head(10)

# %%
data = data.replace('N/A', np.nan)
data['Date Donated'] = pd.to_datetime(data['Date Donated'])
for i in data.columns:
    if i in ['DataSet Name','Data Set Characteristics:','Area:','Attribute Characteristics:','Associated Tasks:','Missing Values?']:  
        data[i] = data[i].str.strip().astype('category')
    else:
        if(i== 'Date Donated'):
            continue
        data[i] = data[i].astype(float)

# %%
data.head(10)
# Out:
#                    DataSet Name Data Set Characteristics:  \
# 0                       Abalone              Multivariate
# 1                         Adult              Multivariate
# 2                     Annealing              Multivariate
# 3  Anonymous Microsoft Web Data                       NaN
# 4                    Arrhythmia              Multivariate
# 5         Artificial Characters              Multivariate
# 6          Audiology (Original)              Multivariate
# 7      Audiology (Standardized)              Multivariate
# 8                      Auto MPG              Multivariate
# 9                    Automobile              Multivariate
#
#    Number of Instances:     Area:  Attribute Characteristics:  \
# 0                4177.0      Life  Categorical, Integer, Real
# 1               48842.0    Social        Categorical, Integer
# 2                 798.0  Physical  Categorical, Integer, Real
# 3               37711.0  Computer                 Categorical
# 4                 452.0      Life  Categorical, Integer, Real
# 5                6000.0  Computer  Categorical, Integer, Real
# 6                 226.0      Life                 Categorical
# 7                 226.0      Life                 Categorical
# 8                 398.0       NaN           Categorical, Real
# 9                 205.0       NaN  Categorical, Integer, Real
#
#    Number of Attributes: Date Donated    Associated Tasks: Missing Values?  \
# 0                    8.0   1995-12-01       Classification              No
# 1                   14.0   1996-05-01       Classification             Yes
# 2                   38.0          NaT       Classification             Yes
# 3                  294.0   1998-11-01  Recommender-Systems             NaN
# 4                  279.0   1998-01-01       Classification             Yes
# 5                    7.0   1992-07-01       Classification              No
# 6                    NaN   1987-12-03       Classification             Yes
# 7                   69.0   1992-08-18       Classification             Yes
# 8                    8.0   1993-07-07           Regression             Yes
# 9                   26.0   1987-05-19           Regression             Yes
#
#    Number of Web Hits:
# 0             673988.0
# 1            1287889.0
# 2             125457.0
# 3             142792.0
# 4             227371.0
# 5             191471.0
# 6              85976.0
# 7              84027.0
# 8             365780.0
# 9             330466.0

# %%
print data.info()
display(HTML(data.describe().to_html()))
print '\n'
print 'Number of NULL'
print '\n'
print data.isnull().sum()
print '\n\n'
print 'Number of UNIQUE'
print '\n'
print data.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 7 columns):
# Name               452 non-null category
# Data Types         433 non-null category
# Default Task       406 non-null category
# Attribute Types    385 non-null category
# # Instances        419 non-null float64
# # Attributes       394 non-null float64
# Year               422 non-null float64
# dtypes: category(4), float64(3)
# memory usage: 39.1 KB
# None
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th># Instances</th>
#       <th># Attributes</th>
#       <th>Year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>count</th>
#       <td>4.190000e+02</td>
#       <td>3.940000e+02</td>
#       <td>422.000000</td>
#     </tr>
#     <tr>
#       <th>mean</th>
#       <td>5.546105e+05</td>
#       <td>2.508921e+04</td>
#       <td>2008.092417</td>
#     </tr>
#     <tr>
#       <th>std</th>
#       <td>4.029254e+06</td>
#       <td>2.255605e+05</td>
#       <td>9.934871</td>
#     </tr>
#     <tr>
#       <th>min</th>
#       <td>1.000000e+01</td>
#       <td>0.000000e+00</td>
#       <td>1987.000000</td>
#     </tr>
#     <tr>
#       <th>25%</th>
#       <td>3.340000e+02</td>
#       <td>9.000000e+00</td>
#       <td>1999.000000</td>
#     </tr>
#     <tr>
#       <th>50%</th>
#       <td>1.950000e+03</td>
#       <td>2.100000e+01</td>
#       <td>2013.000000</td>
#     </tr>
#     <tr>
#       <th>75%</th>
#       <td>1.851000e+04</td>
#       <td>7.075000e+01</td>
#       <td>2016.000000</td>
#     </tr>
#     <tr>
#       <th>max</th>
#       <td>6.300000e+07</td>
#       <td>3.231961e+06</td>
#       <td>2018.000000</td>
#     </tr>
#   </tbody>
# </table>
# Number of NULL
#
#
# Name                0
# Data Types         19
# Default Task       46
# Attribute Types    67
# # Instances        33
# # Attributes       58
# Year               30
# dtype: int64
#
#
#
# Number of UNIQUE
#
#
# Name               452
# Data Types          38
# Default Task        19
# Attribute Types      8
# # Instances        366
# # Attributes       146
# Year                30
# dtype: int64

# %%
region =data.Year.value_counts().sort_index()
plt.figure(figsize=(10,7))
plt.bar(np.arange(len(region.index)),region.values)
plt.xticks(np.arange(len(region.index)), region.index)
plt.xticks(rotation=90)
plt.ylabel('Number of Datasets by year')
plt.xlabel('Year')
plt.show()

# %%
region =data['Default Task'].value_counts().sort_index()
print region
plt.figure(figsize=(10,7))
plt.bar(np.arange(len(region.index)),region.values)
plt.xticks(np.arange(len(region.index)), region.index)
plt.xticks(rotation=90)
plt.ylabel('Number of Datasets')
plt.xlabel('Default Task')
plt.show()
# Out:
# Causal-Discovery                                   4
# Classification                                   242
# Classification, Causal-Discovery                   2
# Classification, Clustering                        44
# Classification, Clustering, Causal-Discovery       2
# Classification, Regression                        29
# Classification, Regression, Clustering            13
# Classification, Regression, Clustering, Causa      1
# Clustering                                        14
# Clustering, Causal-Discovery                       1
# Function-Learning                                  1
# Recommendation                                     1
# Recommender-Systems                                2
# Regression                                        42
# Regression, Classification                         1
# Regression, Clustering                             3
# Regression, Clustering, Causal-Discovery           2
# Regression, Description                            1
# Relational-Learning                                1
# Name: Default Task, dtype: int64

# %%
region =data['Attribute Types'].value_counts().sort_index()
print region
plt.figure(figsize=(10,7))
plt.bar(np.arange(len(region.index)),region.values)
plt.xticks(np.arange(len(region.index)), region.index)
plt.xticks(rotation=90)
plt.ylabel('Number of Datasets')
plt.xlabel('Categories')
plt.show()
# Out:
# Categorical                    38
# Categorical, Integer           28
# Categorical, Integer, Real     20
# Categorical, Real               6
# Categorical, Real, Integer      1
# Integer                        73
# Integer, Real                  60
# Real                          159
# Name: Attribute Types, dtype: int64

# %%
region =data['Data Types'].value_counts().sort_index()
plt.figure(figsize=(10,7))
plt.bar(np.arange(len(region.index)),region.values)
plt.xticks(np.arange(len(region.index)), region.index)
plt.xticks(rotation=90)
plt.ylabel('Number of Datasets')
plt.xlabel('DataTypes')
plt.show()
